# %%
# %%latex
# \begin{align}
# \nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
# \nabla \times \vec{\mathbf{E}}\, +\, \frac1c\, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
# \nabla \cdot \vec{\mathbf{B}} & = 0
# \end{align}
# Out:
# \begin{align}
# \nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
# \nabla \times \vec{\mathbf{E}}\, +\, \frac1c\, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
# \nabla \cdot \vec{\mathbf{B}} & = 0
# \end{align}

# %% [markdown]
# [stack overflow latex](https://stackoverflow.com/questions/13208286/how-to-write-latex-in-ipython-notebook)
#
# [Jupyter reference](https://nbviewer.org/github/ipython/ipython/blob/2.x/examples/Notebook/Display%20System.ipynb#LaTeX)
#
# [Equations Jupyter Ref](https://jupyter-notebook.readthedocs.io/en/latest/examples/Notebook/Typesetting%20Equations.html)
#
# [Good reference](https://blog.deepsim.xyz/equations-symbols-latex-jupyter-notebook/)

# %%
string = "lrvmnir bpr sumvbwvr jx bpr lmiwv yjeryrkbi jx qmbm wibpr xjvni mkd ymibrut jx irhx wi bpr riirkvr jx ymbinlmtmipw utn qmumbr dj w ipmhh but bj rhnvwdmbr bpryjeryrkbi jx bpr qmbm mvvjudwko bj yt wkbrusurbmbwjk lmird jk xjubt trmui jx ibndt  wb wi kjb mk rmit bmiq bj rashmwk rmvp yjeryrkb mkd wbiiwokwxwvmkvr mkd ijyr ynib urymwk nkrashmwkrd bj ower mvjyshrbr rashmkmbwjk jkr cjnhd pmer bj lr fnmhwxwrd mkdwkiswurd bj invp mk rabrkb bpmb pr vjnhd urmvp bpr ibmbrjx rkhwopbrkrd ywkd vmsmlhr jx urvjokwgwko ijnkdhriiijnkd mkd ipmsrhrii ipmsr w dj kjb drry ytirhx bpr xwkmhmnbpjuwbt lnb yt rasruwrkvr cwbp qmbm pmi hrxb kj djnlbbpmb bpr xjhhjcwko wi bpr sujsru msshwvmbwjk mkdwkbrusurbmbwjk w jxxru yt bprjuwri wk bpr pjsr bpmb bprriirkvr jx jqwkmcmk qmumbr cwhh urymwk wkbmvb"
char_counts = {}

for char in string:
    if char in char_counts:
        char_counts[char] += 1
    else:
        char_counts[char] = 1

sorted_char_counts = sorted(char_counts.items(), key=lambda x: x[1], reverse=True)

for char, count in sorted_char_counts:
    print(f"{char}: {count}")
# Out:
#  : 127
# r: 84
# b: 68
# m: 62
# k: 49
# j: 48
# w: 47
# i: 41
# p: 30
# u: 24
# d: 23
# h: 23
# v: 22
# x: 20
# y: 19
# n: 17
# s: 17
# t: 13
# l: 8
# q: 7
# o: 7
# e: 5
# a: 5
# c: 5
# f: 1
# g: 1

# %%
dictionary = {
    "a": "0.0817",
    "b": "0.015",
    "c": "0.0278",
    "d": "0.0525",
    "e": "0.1270",
    "f": "0.0223",
    "g": "0.0202",
    "h": "0.0609",
    "i": "0.0697",
    "j": "0.0015",
    "k": "0.0077",
    "l": "0.0403",
    "m": "0.0241",
    "n": "0.0675",
    "o": "0.0751",
    "q": "0.0010",
    "r": "0.0599",
    "s": "0.0633",
    "t": "0.0906",
    "u": "0.0276",
    "v": "0.0098",
    "w": "0.0236",
    "x": "0.0015",
    "y": "0.0197",
    "z": "0.0007"
}

sorted_dictionary = sorted(dictionary.items(), key=lambda x: x[1], reverse=True)
for k, v in sorted_dictionary:
    print(f"{k}: {v}")
# Out:
# e: 0.1270
# t: 0.0906
# a: 0.0817
# o: 0.0751
# i: 0.0697
# n: 0.0675
# s: 0.0633
# h: 0.0609
# r: 0.0599
# d: 0.0525
# l: 0.0403
# c: 0.0278
# u: 0.0276
# m: 0.0241
# w: 0.0236
# f: 0.0223
# g: 0.0202
# y: 0.0197
# b: 0.015
# v: 0.0098
# k: 0.0077
# j: 0.0015
# x: 0.0015
# q: 0.0010
# z: 0.0007

# %%
key = {
"r":"e",
"b":"t",
"m":"a",
"k":"n",
"j":"o",
"w":"i",
"i":"s",
"p":"h",
"u":"r",
"d":"d",
"h":"l",
"v":"c",
"x":"f",
"y":"m",
"n":"u",
"s":"p",
"t":"y",
"l":"b",
"q":"k",
"o":"g",
"e":"v",
"a":"x",
"c":"c",
"f":"q",
"g":"z"
}

string = "lrvmnir bpr sumvbwvr jx bpr lmiwv yjeryrkbi jx qmbm wibpr xjvni mkd ymibrut jx irhx wi bpr riirkvr jx ymbinlmtmipw utn qmumbr dj w ipmhh but bj rhnvwdmbr bpryjeryrkbi jx bpr qmbm mvvjudwko bj yt wkbrusurbmbwjk lmird jk xjubt trmui jx ibndt  wb wi kjb mk rmit bmiq bj rashmwk rmvp yjeryrkb mkd wbiiwokwxwvmkvr mkd ijyr ynib urymwk nkrashmwkrd bj ower mvjyshrbr rashmkmbwjk jkr cjnhd pmer bj lr fnmhwxwrd mkdwkiswurd bj invp mk rabrkb bpmb pr vjnhd urmvp bpr ibmbrjx rkhwopbrkrd ywkd vmsmlhr jx urvjokwgwko ijnkdhriiijnkd mkd ipmsrhrii ipmsr w dj kjb drry ytirhx bpr xwkmhmnbpjuwbt lnb yt rasruwrkvr cwbp qmbm pmi hrxb kj djnlbbpmb bpr xjhhjcwko wi bpr sujsru msshwvmbwjk mkdwkbrusurbmbwjk w jxxru yt bprjuwri wk bpr pjsr bpmb bprriirkvr jx jqwkmcmk qmumbr cwhh urymwk wkbmvb"
swapped_string = ""
for char in string:
    if char in key:
        substitute = key[char]
        swapped_string += substitute
    else:
        swapped_string += char
    print(swapped_string)
# Out:
# b
# be
# bec
# beca
# becau
# becaus
# because
# because
# because t
# because th
# because the
# because the
# because the p
# because the pr
# because the pra
# because the prac
# because the pract
# because the practi
# because the practic
# because the practice
# because the practice
# because the practice o
# because the practice of
# because the practice of
# because the practice of t
# because the practice of th
# because the practice of the
# because the practice of the
# because the practice of the b
# because the practice of the ba
# because the practice of the bas
# because the practice of the basi
# because the practice of the basic
# because the practice of the basic
# because the practice of the basic m
# because the practice of the basic mo
# because the practice of the basic mov
# because the practice of the basic move
# because the practice of the basic movem
# because the practice of the basic moveme
# because the practice of the basic movemen
# because the practice of the basic movement
# because the practice of the basic movements
# because the practice of the basic movements
# because the practice of the basic movements o
# because the practice of the basic movements of
# because the practice of the basic movements of
# because the practice of the basic movements of k
# because the practice of the basic movements of ka
# because the practice of the basic movements of kat
# because the practice of the basic movements of kata
# because the practice of the basic movements of kata
# because the practice of the basic movements of kata i
# because the practice of the basic movements of kata is
# because the practice of the basic movements of kata ist
# because the practice of the basic movements of kata isth
# because the practice of the basic movements of kata isthe
# because the practice of the basic movements of kata isthe
# because the practice of the basic movements of kata isthe f
# because the practice of the basic movements of kata isthe fo
# because the practice of the basic movements of kata isthe foc
# because the practice of the basic movements of kata isthe focu
# because the practice of the basic movements of kata isthe focus
# because the practice of the basic movements of kata isthe focus
# because the practice of the basic movements of kata isthe focus a
# because the practice of the basic movements of kata isthe focus an
# because the practice of the basic movements of kata isthe focus and
# because the practice of the basic movements of kata isthe focus and
# because the practice of the basic movements of kata isthe focus and m
# because the practice of the basic movements of kata isthe focus and ma
# because the practice of the basic movements of kata isthe focus and mas
# because the practice of the basic movements of kata isthe focus and mast
# because the practice of the basic movements of kata isthe focus and maste
# because the practice of the basic movements of kata isthe focus and master
# because the practice of the basic movements of kata isthe focus and mastery
# because the practice of the basic movements of kata isthe focus and mastery
# because the practice of the basic movements of kata isthe focus and mastery o
# because the practice of the basic movements of kata isthe focus and mastery of
# because the practice of the basic movements of kata isthe focus and mastery of
# because the practice of the basic movements of kata isthe focus and mastery of s
# because the practice of the basic movements of kata isthe focus and mastery of se
# because the practice of the basic movements of kata isthe focus and mastery of sel
# because the practice of the basic movements of kata isthe focus and mastery of self
# because the practice of the basic movements of kata isthe focus and mastery of self
# because the practice of the basic movements of kata isthe focus and mastery of self i
# because the practice of the basic movements of kata isthe focus and mastery of self is
# because the practice of the basic movements of kata isthe focus and mastery of self is
# because the practice of the basic movements of kata isthe focus and mastery of self is t
# because the practice of the basic movements of kata isthe focus and mastery of self is th
# because the practice of the basic movements of kata isthe focus and mastery of self is the
# because the practice of the basic movements of kata isthe focus and mastery of self is the
# because the practice of the basic movements of kata isthe focus and mastery of self is the e
# because the practice of the basic movements of kata isthe focus and mastery of self is the es
# because the practice of the basic movements of kata isthe focus and mastery of self is the ess
# because the practice of the basic movements of kata isthe focus and mastery of self is the esse
# because the practice of the basic movements of kata isthe focus and mastery of self is the essen
# because the practice of the basic movements of kata isthe focus and mastery of self is the essenc
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence o
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of m
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of ma
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of mat
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of mats
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsu
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsub
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsuba
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubay
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubaya
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayas
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayash
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi r
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ry
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu k
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu ka
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu kar
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu kara
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karat
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate d
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i s
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i sh
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i sha
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shal
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall t
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall tr
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try t
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to e
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to el
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elu
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to eluc
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to eluci
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucid
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucida
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidat
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate t
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate th
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate the
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate them
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themo
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themov
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themove
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovem
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themoveme
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovemen
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovement
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements o
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of t
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of th
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the k
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the ka
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kat
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata a
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata ac
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata acc
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata acco
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata accor
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata accord
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata accordi
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata accordin
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according t
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to m
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my i
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my in
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my int
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my inte
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my inter
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interp
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpr
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpre
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpret
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpreta
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretat
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretati
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretatio
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation b
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation ba
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation bas
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation base
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based o
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on f
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on fo
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on for
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on fort
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty y
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty ye
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty yea
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty year
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years o
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of s
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of st
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of stu
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of stud
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  i
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it i
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is n
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is no
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not a
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an e
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an ea
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an eas
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy t
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy ta
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy tas
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task t
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to e
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to ex
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to exp
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to expl
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to expla
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explai
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain e
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain ea
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain eac
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each m
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each mo
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each mov
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each move
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movem
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each moveme
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movemen
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement a
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement an
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and i
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and it
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and its
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itss
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssi
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssig
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssign
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssigni
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssignif
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssignifi
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssignific
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssignifica
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssignifican
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssignificanc
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssignificance
# ...
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssignificance and some must remain unexplained to give acomplete explanation one could have to be qualified andinspired to such an extent that he could reach the stateof enlightened mind capable of recognizing soundlesssound and shapeless shape i do not deem myself the finalauthority but my experience cith kata has left no doubtthat the follocing is the proper application andinterpretation i offer my theories in the hope that theessence of okinacan karate
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssignificance and some must remain unexplained to give acomplete explanation one could have to be qualified andinspired to such an extent that he could reach the stateof enlightened mind capable of recognizing soundlesssound and shapeless shape i do not deem myself the finalauthority but my experience cith kata has left no doubtthat the follocing is the proper application andinterpretation i offer my theories in the hope that theessence of okinacan karate
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssignificance and some must remain unexplained to give acomplete explanation one could have to be qualified andinspired to such an extent that he could reach the stateof enlightened mind capable of recognizing soundlesssound and shapeless shape i do not deem myself the finalauthority but my experience cith kata has left no doubtthat the follocing is the proper application andinterpretation i offer my theories in the hope that theessence of okinacan karate c
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssignificance and some must remain unexplained to give acomplete explanation one could have to be qualified andinspired to such an extent that he could reach the stateof enlightened mind capable of recognizing soundlesssound and shapeless shape i do not deem myself the finalauthority but my experience cith kata has left no doubtthat the follocing is the proper application andinterpretation i offer my theories in the hope that theessence of okinacan karate ci
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssignificance and some must remain unexplained to give acomplete explanation one could have to be qualified andinspired to such an extent that he could reach the stateof enlightened mind capable of recognizing soundlesssound and shapeless shape i do not deem myself the finalauthority but my experience cith kata has left no doubtthat the follocing is the proper application andinterpretation i offer my theories in the hope that theessence of okinacan karate cil
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssignificance and some must remain unexplained to give acomplete explanation one could have to be qualified andinspired to such an extent that he could reach the stateof enlightened mind capable of recognizing soundlesssound and shapeless shape i do not deem myself the finalauthority but my experience cith kata has left no doubtthat the follocing is the proper application andinterpretation i offer my theories in the hope that theessence of okinacan karate cill
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssignificance and some must remain unexplained to give acomplete explanation one could have to be qualified andinspired to such an extent that he could reach the stateof enlightened mind capable of recognizing soundlesssound and shapeless shape i do not deem myself the finalauthority but my experience cith kata has left no doubtthat the follocing is the proper application andinterpretation i offer my theories in the hope that theessence of okinacan karate cill
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssignificance and some must remain unexplained to give acomplete explanation one could have to be qualified andinspired to such an extent that he could reach the stateof enlightened mind capable of recognizing soundlesssound and shapeless shape i do not deem myself the finalauthority but my experience cith kata has left no doubtthat the follocing is the proper application andinterpretation i offer my theories in the hope that theessence of okinacan karate cill r
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssignificance and some must remain unexplained to give acomplete explanation one could have to be qualified andinspired to such an extent that he could reach the stateof enlightened mind capable of recognizing soundlesssound and shapeless shape i do not deem myself the finalauthority but my experience cith kata has left no doubtthat the follocing is the proper application andinterpretation i offer my theories in the hope that theessence of okinacan karate cill re
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssignificance and some must remain unexplained to give acomplete explanation one could have to be qualified andinspired to such an extent that he could reach the stateof enlightened mind capable of recognizing soundlesssound and shapeless shape i do not deem myself the finalauthority but my experience cith kata has left no doubtthat the follocing is the proper application andinterpretation i offer my theories in the hope that theessence of okinacan karate cill rem
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssignificance and some must remain unexplained to give acomplete explanation one could have to be qualified andinspired to such an extent that he could reach the stateof enlightened mind capable of recognizing soundlesssound and shapeless shape i do not deem myself the finalauthority but my experience cith kata has left no doubtthat the follocing is the proper application andinterpretation i offer my theories in the hope that theessence of okinacan karate cill rema
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssignificance and some must remain unexplained to give acomplete explanation one could have to be qualified andinspired to such an extent that he could reach the stateof enlightened mind capable of recognizing soundlesssound and shapeless shape i do not deem myself the finalauthority but my experience cith kata has left no doubtthat the follocing is the proper application andinterpretation i offer my theories in the hope that theessence of okinacan karate cill remai
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssignificance and some must remain unexplained to give acomplete explanation one could have to be qualified andinspired to such an extent that he could reach the stateof enlightened mind capable of recognizing soundlesssound and shapeless shape i do not deem myself the finalauthority but my experience cith kata has left no doubtthat the follocing is the proper application andinterpretation i offer my theories in the hope that theessence of okinacan karate cill remain
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssignificance and some must remain unexplained to give acomplete explanation one could have to be qualified andinspired to such an extent that he could reach the stateof enlightened mind capable of recognizing soundlesssound and shapeless shape i do not deem myself the finalauthority but my experience cith kata has left no doubtthat the follocing is the proper application andinterpretation i offer my theories in the hope that theessence of okinacan karate cill remain
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssignificance and some must remain unexplained to give acomplete explanation one could have to be qualified andinspired to such an extent that he could reach the stateof enlightened mind capable of recognizing soundlesssound and shapeless shape i do not deem myself the finalauthority but my experience cith kata has left no doubtthat the follocing is the proper application andinterpretation i offer my theories in the hope that theessence of okinacan karate cill remain i
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssignificance and some must remain unexplained to give acomplete explanation one could have to be qualified andinspired to such an extent that he could reach the stateof enlightened mind capable of recognizing soundlesssound and shapeless shape i do not deem myself the finalauthority but my experience cith kata has left no doubtthat the follocing is the proper application andinterpretation i offer my theories in the hope that theessence of okinacan karate cill remain in
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssignificance and some must remain unexplained to give acomplete explanation one could have to be qualified andinspired to such an extent that he could reach the stateof enlightened mind capable of recognizing soundlesssound and shapeless shape i do not deem myself the finalauthority but my experience cith kata has left no doubtthat the follocing is the proper application andinterpretation i offer my theories in the hope that theessence of okinacan karate cill remain int
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssignificance and some must remain unexplained to give acomplete explanation one could have to be qualified andinspired to such an extent that he could reach the stateof enlightened mind capable of recognizing soundlesssound and shapeless shape i do not deem myself the finalauthority but my experience cith kata has left no doubtthat the follocing is the proper application andinterpretation i offer my theories in the hope that theessence of okinacan karate cill remain inta
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssignificance and some must remain unexplained to give acomplete explanation one could have to be qualified andinspired to such an extent that he could reach the stateof enlightened mind capable of recognizing soundlesssound and shapeless shape i do not deem myself the finalauthority but my experience cith kata has left no doubtthat the follocing is the proper application andinterpretation i offer my theories in the hope that theessence of okinacan karate cill remain intac
# because the practice of the basic movements of kata isthe focus and mastery of self is the essence of matsubayashi ryu karate do i shall try to elucidate themovements of the kata according to my interpretation based on forty years of study  it is not an easy task to explain each movement and itssignificance and some must remain unexplained to give acomplete explanation one could have to be qualified andinspired to such an extent that he could reach the stateof enlightened mind capable of recognizing soundlesssound and shapeless shape i do not deem myself the finalauthority but my experience cith kata has left no doubtthat the follocing is the proper application andinterpretation i offer my theories in the hope that theessence of okinacan karate cill remain intact
